# %% [markdown]
# # Instrumental variables example

# %% [markdown]
# See https://github.com/BasisResearch/chirho/issues/18

# %%
import pyro
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from pyro.nn import PyroModule, PyroSample
from torch import nn
import torch
import pyro.distributions as dist
from chirho.observational.handlers import condition
from chirho.observational.handlers.predictive import PredictiveModel
from chirho.counterfactual.handlers import MultiWorldCounterfactual
from chirho.indexed.ops import IndexSet, gather
from chirho.interventional.handlers import do
from pyro.infer.autoguide import AutoNormal
from pyro.infer import SVI, Trace_ELBO, Predictive
import functools
from chirho.robust.handlers.estimators import MonteCarloInfluenceEstimator, one_step_corrected_estimator 
from typing import Callable
from tqdm import tqdm

torch.set_default_device('cpu')

smoke_test = "CI" in os.environ

# %% [markdown]
# ## Outline
#
# * Overview
#     * General background on instrumental variables
#         - Chapter 9 in Neal 2020
#         - Pearl Casuality Chapter 8.2
#         - Mixtape Chapter "Instrumental Variables" p.315
#     * Warm-up: linear outcome
#     * (Nonparametric) Identification impossible without parametric assumptions
#     * Example Problem - paper
#         - https://github.com/jhartford/DeepIV
#         - http://proceedings.mlr.press/v70/hartford17a/hartford17a.pdf
#         - http://proceedings.mlr.press/v70/hartford17a.html
#         - Key assumption: additive unobserved confounders ("semi-parametric approach")
#     * Dataset
#
# * Casual Probabilistic Program
#
# * Casual Query
#
# * Results

# %% [markdown]
# ## Setup
#
# * Data generation process is given by an explicit parametric model
# * The inference model is using a generic distribution for the treatment variable - a mixture of Gaussians
# * The structural model for the outcome given the treatment - ???
# * The intervention will be on the treatment (not on the instrument!) - check this!

# %% [markdown]
# ## Linear model - warmup

# %% [markdown]
# Linear model $(X,Y): Y_i \sim \alpha X_i + \beta + \epsilon_i$ where
# - $\alpha,\beta \sim N(0,10)$
# - $X_i \sim Unif(-1,1)$
# - $\epsilon_i \sim N(0,\sigma)$
# - $\sigma \sim Unif(1,2)$

# %% [markdown]
# ### Data generation

# %%
def linear_model_bayesian_direct(X=None, Y=None):
    # Priors for slope and intercept
    slope = pyro.sample('alpha', dist.Normal(0, 10))
    intercept = pyro.sample('beta', dist.Normal(0, 10))
    sigma = pyro.sample('sigma', dist.Uniform(1, 2))

    # Linear model
    n = len(X) if X is not None else 1
    # Likelihood
    with pyro.plate('data', n, dim=-1):
        x = pyro.sample('x', dist.Uniform(-1,1), obs=X)
        mean = slope * x + intercept
        y = pyro.sample('y', dist.Normal(mean, sigma), obs=Y)

    return y

pyro.render_model(linear_model_bayesian_direct)

# %%
def draw_and_plot_samples(model, **kwargs):
    from pyro.poutine import trace

    tr = trace(model).get_trace(**kwargs)
    x, y = tr.nodes['x']['value'], tr.nodes['y']['value']
    alpha, beta, sigma = tr.nodes['alpha']['value'], tr.nodes['beta']['value'], tr.nodes['sigma']['value']

    plt.scatter(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    # format to 2 decimal points
    plt.title(f'alpha = {alpha:.2f}, beta = {beta:.2f}, sigma = {sigma:.2f}')
    plt.show()

    return x,y

draw_and_plot_samples(linear_model_bayesian_direct)

# %%
# sample from the model
# generate random x between 0 and 1
n = 200
x = torch.linspace(-2,2,n)
draw_and_plot_samples(linear_model_bayesian_direct,X=x)

# %%
class LinearModel(PyroModule):
    def __init__(self, n):
        super().__init__()
        self.n = n
    
    def forward(self, slope,intercept,sigma, x=None, y=None):
        with pyro.plate('data', self.n, dim=-1):
            x = pyro.sample('x', dist.Uniform(-1,1), obs=x)
            mean = slope * x + intercept
            y = pyro.sample('y', dist.Normal(mean, sigma), obs=y)
        return x,y
    
n = 200
linear_model = LinearModel(n)

pyro.render_model(linear_model,(-0.5, 1.1, 0.01))

# %%
class BayesianLinearModel(PyroModule):
    def __init__(self, n):
        super().__init__()

        self.n = n
        self.linear_model = LinearModel(self.n)
    
    def forward(self, x=None, y=None):
        alpha = pyro.sample('alpha',dist.Normal(0,100))
        beta = pyro.sample('beta',dist.Uniform(-2, 2))
        sigma = pyro.sample('sigma',dist.Uniform(0,2))
        return self.linear_model(beta,alpha,sigma,x, y)

# sample from the model and plot the pairs (x,y)
n = 200
bayesian_model = BayesianLinearModel(n)

pyro.render_model(bayesian_model)

# %%
draw_and_plot_samples(bayesian_model)

# %%
class ConditionedLinearModel(PyroModule):
    def __init__(self, n: int):
        super().__init__()
        self.n = n
        self.causal_linear_model = BayesianLinearModel(self.n)

    def forward(self, x=None, y=None):
        with condition(data={'x': x, 'y': y}):
            return self.causal_linear_model(x,y)

x = torch.linspace(-2,2,n)   
conditioned_model = ConditionedLinearModel(n)

pyro.render_model(conditioned_model, (x,))

# %%
x,y = draw_and_plot_samples(conditioned_model, x=x)

# %%
alpha, beta, sigma = torch.tensor(20), torch.tensor(-1.5), torch.tensor(0.01)
true_generative_model = pyro.condition(bayesian_model, data={'alpha': alpha, 'beta': beta, 'sigma': sigma})
pyro.render_model(true_generative_model)

# %%
x,y=draw_and_plot_samples(true_generative_model)

# %% [markdown]
# ### Toy exercise - identifying the casual effect of $X\to Y$ with ChiRho

# %%
class LinearATE(PyroModule):
    def __init__(self, n : int):
        super().__init__()
        self.n = n
        self.observational_model = ConditionedLinearModel(self.n)

    def forward(self, x_obs, y_obs):
        with MultiWorldCounterfactual(), do(actions=dict(x=(-0.5,0.5))):
            _, y_all = self.observational_model(x=x_obs, y=y_obs)
            y_cf_1 = gather(y_all, IndexSet(x={2}))
            y_cf_0 = gather(y_all, IndexSet(x={1}))
        
        ate =  (y_cf_1 - y_cf_0).mean()
        return pyro.deterministic("ATE", ate, event_dim=0)
        
ate_model = LinearATE(len(x))
pyro.render_model(ate_model, (x,y))

# %%
ate_model(x,y)

# %% [markdown]
# #### Causal inference is probabilistic inference

# %%
num_iterations = 5000 if not smoke_test else 10

pyro.clear_param_store()

adam = pyro.optim.Adam({"lr": 0.03})

ate_guide = AutoNormal(ate_model)

svi = SVI(ate_model, ate_guide, adam, loss=Trace_ELBO())

for j in range(num_iterations):
    # calculate the loss and take a gradient step
    loss = svi.step(x,y)
    if j % 1000 == 0:
        print("[iteration %04d] loss: %.4f" % (j + 1, loss))

# %%
# Create Predictive object
predictive = Predictive(ate_model, guide=ate_guide, num_samples=5000)

# Make predictions
predictions = predictive(x,y)

# Extract predictions
predicted_ates = predictions["ATE"].squeeze()

# plot histogram
sns.histplot(predicted_ates, bins=20, kde=True)
plt.xlabel('ATE')
plt.ylabel('Density')
plt.title('ATE posterior distribution')
plt.show()

# %% [markdown]
# ## The linear instrumental variable setup

# %% [markdown]
# ### Model

# %%
class BayesianLinearGaussianSCM(PyroModule):
    def __init__(self):
        super().__init__()

    @PyroSample
    def alpha(self):
        return dist.Normal(0,10)

    @PyroSample
    def beta(self):
        return dist.Normal(0, 10)
    
    @PyroSample
    def gamma(self):
        return dist.Normal(0, 10)
    
    @PyroSample
    def delta(self):
        return dist.Normal(0, 10)
    
    @PyroSample
    def sigmaZ(self):
        return dist.Uniform(0,2)
    
    @PyroSample
    def sigmaH(self):
        return dist.Uniform(0,2)
    
    @PyroSample
    def sigmaX(self):
        return dist.Uniform(0,2)
    
    @PyroSample
    def sigmaY(self):
        return dist.Uniform(0,2)
    
    @PyroSample
    def meanH(self):
        return dist.Normal(0,2)
    
    def forward(self):
        Z = pyro.sample('Z',dist.Normal(0,self.sigmaZ))
        H = pyro.sample('H',dist.Normal(self.meanH, self.sigmaH))
        X = pyro.sample('X',dist.Normal(self.beta * Z + self.gamma * H, self.sigmaX))
        Y = pyro.sample('Y',dist.Normal(self.alpha * X + self.delta * H, self.sigmaY))
        return X,Y

pyro.render_model(BayesianLinearGaussianSCM())

# %%
class ObservedBayesianLinearGaussianSCM(BayesianLinearGaussianSCM):
    def __init__(self):
        super().__init__()

    def forward(self, X : torch.tensor, Y: torch.tensor,Z : torch.tensor):
        self.alpha, self.beta, self.gamma, self.delta, self.sigmaZ, self.sigmaH, self.sigmaX, self.sigmaY, self.meanH
        with condition(data={'Z': Z, 'X' : X, 'Y': Y}):
            with pyro.plate("data", Z.shape[0], dim=-1):
                return super().forward()
            

pyro.render_model(lambda : ObservedBayesianLinearGaussianSCM()(Z=torch.rand(10), X=torch.rand(10), Y=torch.rand(10)))

# %% [markdown]
# ### Data

# %%
class GroundTruthModel(BayesianLinearGaussianSCM):
    def __init__(self, alpha, beta, gamma, delta, sigmaZ, sigmaH, sigmaX, sigmaY, meanH):
        super().__init__()
        self._alpha = alpha
        self._beta = beta
        self._gamma = gamma
        self._delta = delta
        self._sigmaZ = sigmaZ
        self._sigmaH = sigmaH
        self._sigmaX = sigmaX
        self._sigmaY = sigmaY
        self._meanH = meanH


    @property
    def alpha(self):
        return self._alpha
    
    @property
    def beta(self):
        return self._beta
    
    @property
    def gamma(self):
        return self._gamma
    
    @property
    def delta(self):
        return self._delta
    
    @property
    def sigmaZ(self):
        return self._sigmaZ
    
    @property
    def sigmaH(self):
        return self._sigmaH
    
    @property
    def sigmaX(self):
        return self._sigmaX
    
    @property
    def sigmaY(self):
        return self._sigmaY
    
    @property
    def meanH(self):
        return self._meanH
    

true_alpha, true_beta, true_gamma, true_delta = torch.tensor(1.5), torch.tensor(2.0), torch.tensor(2.0), torch.tensor(-10.5)
true_sigmaZ, true_sigmaH, true_sigmaX, true_sigmaY = torch.tensor(1.0), torch.tensor(1.8), torch.tensor(1.0), torch.tensor(1.0)
true_meanH = torch.tensor(1.0)

num_samples = 100000

gt_model = GroundTruthModel(true_alpha, true_beta, true_gamma, true_delta, true_sigmaZ, true_sigmaH, true_sigmaX, true_sigmaY, true_meanH)

# sample from the model
with pyro.plate('samples', num_samples):
    tr=pyro.poutine.trace(gt_model).get_trace()

x_obs,y_obs,z_obs=[tr.nodes[name]['value'] for name in ['X','Y','Z']]

pyro.render_model(gt_model)

# %%
sns.pairplot(pd.DataFrame({'X':x_obs,'Y':y_obs,'Z':z_obs}))
plt.show()

# %% [markdown]
# Sanity check: the ATE on the ground truth model should give the alpha coefficient

# %%
num_mc_samples = 1000

with MultiWorldCounterfactual(), do(actions=dict(X=(0.,1.))), pyro.plate('monte_carlo_samples', num_mc_samples):
    x_all,y_all = gt_model()
    y_cf_1 = gather(y_all, IndexSet(X={2}))
    y_cf_0 = gather(y_all, IndexSet(X={1}))
    ate = (y_cf_1 - y_cf_0).mean()
    print(f'ate_direct={ate}')

# now the two-stage approach
with MultiWorldCounterfactual(), do(actions=dict(Z=(0.,1.))),  pyro.plate('monte_carlo_samples', num_mc_samples):
    x_all,y_all = gt_model()
    y_cf_1 = gather(y_all, IndexSet(Z={2}))
    y_cf_0 = gather(y_all, IndexSet(Z={1}))

    x_cf_1 = gather(x_all, IndexSet(Z={2}))
    x_cf_0 = gather(x_all, IndexSet(Z={1}))

    xz = (x_cf_1 - x_cf_0).mean()
    yz = (y_cf_1 - y_cf_0).mean()

    ate = yz / xz
    print(f'xz = {xz}, yz = {yz}, ate_2sls = {ate}')
# Out:
# ate_direct=1.499152421951294
# xz = 1.9854227304458618, yz = 3.0465028285980225, ate_2sls = 1.5344353914260864

# %% [markdown]
# ### Conditional distributions

# %%
# sample from the model
zz = torch.tensor(-10.0)
with condition(data={'Z': zz}), pyro.plate('samples', num_samples):
    xx, yy = gt_model()

# pairplot
df = pd.DataFrame({'X': xx, 'Y': yy})
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Original query

# %%
class LinearInstrumentalATE(PyroModule):
    def __init__(self, causal_model : Callable):
        super().__init__()
        self.model = causal_model

    def forward(self, x_obs=None, y_obs=None, z_obs=None):
        with MultiWorldCounterfactual(), do(actions=dict(X=(0.,1.))):
            _, y_all = self.model(X=x_obs, Y=y_obs, Z=z_obs)
            y_cf_1 = gather(y_all, IndexSet(X={2}))
            y_cf_0 = gather(y_all, IndexSet(X={1}))
        
        ate =  (y_cf_1 - y_cf_0).mean()
        return pyro.deterministic("ATE", ate, event_dim=0)
        
pyro.render_model(lambda : LinearInstrumentalATE(ObservedBayesianLinearGaussianSCM())(z_obs=torch.rand(10), x_obs=torch.rand(10), y_obs=torch.rand(10)))

# %% [markdown]
# ### Option 1 - inference on the original model

# %%
num_iterations = 15000 if not smoke_test else 10

pyro.clear_param_store()

obs_model = ObservedBayesianLinearGaussianSCM()
obs_guide = AutoNormal(obs_model)
# obs_guide = pyro.infer.autoguide.AutoMultivariateNormal(obs_model)

# svi = SVI(obs_model, obs_guide, pyro.optim.Adam({"lr": 0.01}), loss=Trace_ELBO())
elbo = pyro.infer.Trace_ELBO()(obs_model, obs_guide)

elbo(X=x_obs,Y=y_obs,Z=z_obs)

adam = torch.optim.Adam(elbo.parameters(), lr=0.001)
losses = []
pbar = tqdm(range(num_iterations))
pbar.set_description(f'loss=Inf')
for j in pbar:
    adam.zero_grad()
    loss = elbo(X=x_obs,Y=y_obs,Z=z_obs)
    loss.backward()
    losses.append(loss.item())
    adam.step()
    if (j + 1) % 100 == 0:
        pbar.set_description(f'loss={loss.item()}')
    #     print("[iteration %04d] loss: %.4f" % (j + 1, loss))

# for j in range(num_iterations):
#     # calculate the loss and take a gradient step
#     loss = svi.step(X=x_obs,Y=y_obs,Z=z_obs)
#     if (j + 1) % 1000 == 0:
#         print("[iteration %04d] loss: %.4f" % (j + 1, loss))

# plot loss
plt.semilogy(losses)
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('Loss over iterations')
plt.show()
# Out:
# loss=731533.6875: 100%|██████████| 15000/15000 [03:34<00:00, 69.82it/s]

# %% [markdown]
# Will this work?

# %%
pyro.render_model(LinearInstrumentalATE(PredictiveModel(ObservedBayesianLinearGaussianSCM(),obs_guide)),(x_obs,y_obs,z_obs))

# %%
num_mc_samples = 2000
with MultiWorldCounterfactual(), do(actions=dict(X=(0.,1.))), pyro.plate('monte_carlo_samples', num_mc_samples, dim=-2):
    x_all,y_all = PredictiveModel(ObservedBayesianLinearGaussianSCM(),obs_guide)(x_obs,y_obs,z_obs)
    y_cf_1 = gather(y_all, IndexSet(X={2}))
    y_cf_0 = gather(y_all, IndexSet(X={1}))
    ate = (y_cf_1 - y_cf_0).mean()
    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}')
    print(f'ate_direct={ate}')

# now the two-stage approach
with MultiWorldCounterfactual(), do(actions=dict(Z=(0.,1.))), pyro.plate('monte_carlo_samples', num_mc_samples, dim=-2):
    x_all,y_all = PredictiveModel(ObservedBayesianLinearGaussianSCM(),obs_guide)(x_obs,y_obs,z_obs)
    y_cf_1 = gather(y_all, IndexSet(Z={2}))
    y_cf_0 = gather(y_all, IndexSet(Z={1}))

    x_cf_1 = gather(x_all, IndexSet(Z={2}))
    x_cf_0 = gather(x_all, IndexSet(Z={1}))

    xz = (x_cf_1 - x_cf_0).mean()
    yz = (y_cf_1 - y_cf_0).mean()

    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}, X: {x_cf_1.shape}, {x_cf_0.shape}')

    ate = yz / xz
    print(f'xz = {xz}, yz = {yz}, ate_2sls = {ate}')

# plot the distributions
sns.histplot((y_cf_1-y_cf_0).mean(dim=-1).squeeze().detach().numpy(), bins=20, kde=True, color='blue', label='Y-Z')
sns.histplot((x_cf_1-x_cf_0).mean(dim=-1).squeeze().detach().numpy(), bins=20, kde=True, color='red', label='X-Z')
sns.histplot(((y_cf_1-y_cf_0).mean(dim=-1)/(x_cf_1-x_cf_0).mean(dim=-1)).squeeze().detach().numpy(), bins=20, kde=True, color='green', label='ATE')
plt.xlabel('ATE')
plt.ylabel('Density')
plt.title(f'ATE posterior distribution:\nTrue XY={true_alpha}, XZ={true_beta}, YZ={true_alpha*true_beta}')
plt.legend()
plt.show()
# Out:
# Shapes Y: torch.Size([1, 1, 1, 2000, 100000]), torch.Size([1, 1, 1, 2000, 100000])
# ate_direct=-0.8793350458145142
# Shapes Y: torch.Size([1, 1, 1, 2000, 100000]), torch.Size([1, 1, 1, 2000, 100000]), X: torch.Size([1, 1, 1, 2000, 100000]), torch.Size([1, 1, 1, 2000, 100000])
# xz = 3.5121371746063232, yz = -3.0869948863983154, ate_2sls = -0.8789505362510681

# %%
class LinearInstrumentalATE2(torch.nn.Module):
    def __init__(self, causal_model : Callable, num_monte_carlo : int = 1000):
        super().__init__()
        self.model = causal_model
        self.num_monte_carlo = num_monte_carlo

    def forward(self, *args, **kwargs):
        with MultiWorldCounterfactual():
            with pyro.plate("monte_carlo_functional", size=self.num_monte_carlo, dim=-2):
                with do(actions=dict(X=(torch.tensor(0.),torch.tensor(1.)))):
                    _, y_all = self.model(*args, **kwargs)
                y_cf_1 = gather(y_all, IndexSet(X={2}), event_dim=0)
                y_cf_0 = gather(y_all, IndexSet(X={1}), event_dim=0)
        
        ate = (y_cf_1 - y_cf_0).mean(dim=-2, keepdim=True).mean(dim=-1, keepdim=True).squeeze()
        return pyro.deterministic("ATE", ate)
        
pyro.render_model(LinearInstrumentalATE2(gt_model))

# %% [markdown]
# Smoke test: ATE on the ground truth

# %%
LinearInstrumentalATE2(gt_model)()
# Out:
# tensor(1.5260)

# %% [markdown]
# ### Option 2 - inference on the counterfactual model

# %%
num_iterations = 5000 if not smoke_test else 10

pyro.clear_param_store()

ate_model = LinearInstrumentalATE(ObservedBayesianLinearGaussianSCM())
ate_guide = AutoNormal(ate_model)

svi = SVI(ate_model, ate_guide, pyro.optim.Adam({"lr": 0.05}), loss=Trace_ELBO())

for j in range(num_iterations):
    # calculate the loss and take a gradient step
    loss = svi.step(x_obs,y_obs,z_obs)
    if (j + 1) % 1000 == 0:
        print("[iteration %04d] loss: %.4f" % (j + 1, loss))

# %%
# Make predictions
instrumental_predicted_ates = Predictive(ate_model, guide=ate_guide, num_samples=1000)(x_obs,y_obs,z_obs)["ATE"].squeeze()

# plot histogram
sns.histplot(instrumental_predicted_ates, bins=20, kde=True)
plt.xlabel('ATE')
plt.ylabel('Density')
plt.title(f'ATE posterior distribution (true effect = {true_alpha.item()})')
plt.show()

# %% [markdown]
# We have a biased estimate, even though we've observed the instrument.

# %% [markdown]
# ### Two-stage least squares : direct solution

# %%
# linear regression model for Z~X, find the coefficient

beta_lsq = torch.linalg.lstsq(torch.cat((z_obs.unsqueeze(-1),torch.ones_like(z_obs).unsqueeze(-1)),dim=1), x_obs.unsqueeze(-1)).solution[0]

alpha_lsq = torch.linalg.lstsq(torch.cat((beta_lsq*z_obs.unsqueeze(-1),torch.ones_like(z_obs).unsqueeze(-1)),dim=1), y_obs.unsqueeze(-1)).solution[0]

print(f'true: {true_alpha}, estimated: {alpha_lsq}')
# Out:
# true: 1.5, estimated: tensor([1.4549])

# %% [markdown]
# ### Reduced model to identify the effect by approximating the distribution

# %%
# create a reduced model, where we have Z,X,Y only with Gaussian distributions, such that X|Z ~ N(beta*Z, sigmaX), Y|Z ~ N(alpha*beta*Z, sigmaY)

class ReducedBayesianLinearGaussianSCM(PyroModule):
    def __init__(self):
        super().__init__()

    @PyroSample
    def alpha(self):
        return dist.Normal(0,10)

    @PyroSample
    def beta(self):
        return dist.Normal(0, 10)
    
    @PyroSample
    def sigmaX(self):
        return dist.Uniform(0,10)
    
    @PyroSample
    def sigmaY(self):
        return dist.Uniform(0,10)
    
    @PyroSample
    def sigmaZ(self):
        return dist.Uniform(0,10)

    def forward(self):
        Z = pyro.sample('Z',dist.Normal(0,self.sigmaZ))
        X = pyro.sample('X',dist.Normal(self.beta * Z, self.sigmaX))
        Y = pyro.sample('Y',dist.Normal(self.alpha * Z, self.sigmaY))
        return X,Y

pyro.render_model(ReducedBayesianLinearGaussianSCM())

# %%
class ReducedObservedBayesianLinearGaussianSCM(ReducedBayesianLinearGaussianSCM):
    def __init__(self):
        super().__init__()
        
    def forward(self, X : torch.tensor, Y: torch.tensor,Z : torch.tensor):
        self.alpha, self.beta, self.sigmaZ, self.sigmaX, self.sigmaY
        with condition(data={'Z': Z, 'X' : X, 'Y': Y}):
            with pyro.plate("data", Z.shape[0], dim=-1):
                return super().forward()

pyro.render_model(lambda : ReducedObservedBayesianLinearGaussianSCM()(X=x_obs,Y=y_obs,Z=z_obs))

# %%
# Probabilistic inference for the reduced model
num_iterations = 10000 if not smoke_test else 10

pyro.clear_param_store()

obs_model_reduced = ReducedObservedBayesianLinearGaussianSCM()
obs_guide_reduced = AutoNormal(obs_model_reduced)

elbo = pyro.infer.Trace_ELBO()(obs_model_reduced, obs_guide_reduced)

elbo(X=x_obs,Y=y_obs,Z=z_obs)

adam = torch.optim.Adam(elbo.parameters(), lr=0.01)
losses = []
pbar = tqdm(range(num_iterations))
pbar.set_description(f'loss=Inf')
for j in pbar:
    adam.zero_grad()
    loss = elbo(X=x_obs,Y=y_obs,Z=z_obs)
    loss.backward()
    losses.append(loss.item())
    adam.step()
    if (j + 1) % 50 == 0:
        pbar.set_description(f'loss={loss.item()}')

# plot loss
plt.semilogy(losses)
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('Loss over iterations')
plt.show()

# svi = SVI(obs_model_reduced, obs_guide_reduced, pyro.optim.Adam({"lr": 0.1}), loss=Trace_ELBO())

# for j in range(num_iterations):
#     # calculate the loss and take a gradient step
#     loss = svi.step(X=x_obs,Y=y_obs,Z=z_obs)
#     if (j + 1) % 500 == 0:
#         print("[iteration %04d] loss: %.4f" % (j + 1, loss))
# Out:
# loss=872439.9375: 100%|██████████| 10000/10000 [00:59<00:00, 168.51it/s]

# %%
num_mc_samples = 5000
with MultiWorldCounterfactual(), do(actions=dict(X=(0.,1.))), pyro.plate('monte_carlo_samples', num_mc_samples, dim=-2):
    x_all,y_all = PredictiveModel(ReducedObservedBayesianLinearGaussianSCM(),obs_guide_reduced)(x_obs,y_obs,z_obs)
    y_cf_1 = gather(y_all, IndexSet(X={2}))
    y_cf_0 = gather(y_all, IndexSet(X={1}))
    ate = (y_cf_1 - y_cf_0).mean()
    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}')
    print(f'ate_direct={ate}')

# now the two-stage approach
with MultiWorldCounterfactual(), do(actions=dict(Z=(0.,1.))), pyro.plate('monte_carlo_samples', num_mc_samples, dim=-2):
    x_all,y_all = PredictiveModel(ReducedObservedBayesianLinearGaussianSCM(),obs_guide_reduced)(x_obs,y_obs,z_obs)
    y_cf_1 = gather(y_all, IndexSet(Z={2}))
    y_cf_0 = gather(y_all, IndexSet(Z={1}))

    x_cf_1 = gather(x_all, IndexSet(Z={2}))
    x_cf_0 = gather(x_all, IndexSet(Z={1}))

    xz = (x_cf_1 - x_cf_0).mean()
    yz = (y_cf_1 - y_cf_0).mean()

    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}, X: {x_cf_1.shape}, {x_cf_0.shape}')

    ate = yz / xz
    print(f'xz = {xz}, yz = {yz}, ate_2sls = {ate}')

# plot the distributions
sns.histplot((y_cf_1-y_cf_0).mean(dim=-1).squeeze().detach().numpy(), bins=20, kde=True, color='blue', label='Y-Z')
sns.histplot((x_cf_1-x_cf_0).mean(dim=-1).squeeze().detach().numpy(), bins=20, kde=True, color='red', label='X-Z')
sns.histplot(((y_cf_1-y_cf_0).mean(dim=-1)/(x_cf_1-x_cf_0).mean(dim=-1)).squeeze().detach().numpy(), bins=20, kde=True, color='green', label='ATE')
plt.xlabel('ATE')
plt.ylabel('Density')
plt.title(f'ATE posterior distribution:\nTrue XY={true_alpha}, XZ={true_beta}, YZ={true_alpha*true_beta}')
plt.legend()
plt.show()
# Out:
# Shapes Y: torch.Size([100000]), torch.Size([100000])
# ate_direct=0.0
# Shapes Y: torch.Size([1, 1, 1, 5000, 100000]), torch.Size([1, 1, 1, 5000, 100000]), X: torch.Size([1, 1, 1, 5000, 100000]), torch.Size([1, 1, 1, 5000, 100000])
# xz = 2.0097415447235107, yz = 2.926910877227783, ate_2sls = 1.4563618898391724

# %% [markdown]
# The standard counterfactual ATE is indeed zero in this model, as we have broken the causal relationships between X and Y.

# %% [markdown]
# ### The "Chirho Robust Way" - TODO

# %%
dataset = dict(X=x_obs, Y=y_obs, Z=z_obs)

[(k,dataset[k].shape) for k in dataset.keys()]

# %%
functional = functools.partial(LinearInstrumentalATE2, num_monte_carlo = 100)
ate_plug_in = functional(
    PredictiveModel(ObservedBayesianLinearGaussianSCM(), obs_guide)
)(Z=z_obs, X=x_obs, Y=y_obs)

functional2 = functools.partial(LinearInstrumentalATE2, num_monte_carlo = 100)

with MonteCarloInfluenceEstimator(num_samples_outer=10, num_samples_inner=2):
    automated_monte_carlo_correction = one_step_corrected_estimator(functional2, dataset)(
        PredictiveModel(obs_model,obs_guide)
    )(Z=z_obs, X=x_obs, Y=y_obs)

print(f'ATE plug-in: {ate_plug_in}, ATE corrected: {automated_monte_carlo_correction}')

# %% [markdown]
# ## The General Case - Deep IV

# %% [markdown]
# The idea is to parametrize the $X|Z \sim F(x\mid z)$ by a deep network, and recover the causal effect $Y\sim g_0(X)$ by solving the integral equation
# $$
# E[y \mid z]=E\left[g_0\left(x\right) \mid z\right]=\int g_0\left(x\right) dF(x \mid z)
# $$

# %%
from torchvision.ops import MLP

class FDistribution(PyroModule):
    def __init__(self, z_dim, x_dim, hidden_dim):
        super().__init__()
        self.mean_dist = PyroModule[MLP](z_dim,[hidden_dim]*3 + [x_dim], dropout=0.01)
        self.var_dist = PyroModule[MLP](z_dim,[hidden_dim]*3 + [x_dim], dropout=0.01)
    
    def forward(self, z):
        # print(f'FDistribution(z.shape={z.shape}, z.dim={z.dim()}')
        z = z.reshape(-1,1)
        # if z.dim() == 1:
        #     z = z.unsqueeze(-1)
        x_mean = self.mean_dist(z)
        x_std = torch.exp(self.var_dist(z))  # Ensure the standard deviation is positive
        return dist.Normal(x_mean, x_std).to_event(1)

class GFunction(PyroModule):
    def __init__(self, x_dim, hidden_dim):
        super().__init__()
        # self.fc1 = PyroModule[nn.Linear](x_dim, hidden_dim)
        # self.fc2 = PyroModule[nn.Linear](hidden_dim, hidden_dim)
        # self.fc3 = PyroModule[nn.Linear](hidden_dim, 1)
        self.mlp = PyroModule[MLP](x_dim,[hidden_dim]*3 + [1], dropout=0.01)
    
    def forward(self, x):
        # print(f'GFunction(x.shape={x.shape}, x.dim={x.dim()})')
        # if x.dim() == 1:
        #     x = x.unsqueeze(-1)
        x = x.reshape(-1,1)
        # h = torch.tanh(self.fc2(torch.tanh(self.fc1(x))))
        # y_mean = self.fc3(h)
        y_mean = self.mlp(x)
        return y_mean[:,0]

class NoiseDistribution(PyroModule):
    def __init__(self, x_dim, hidden_dim):
        super().__init__()
        self.std_dist = PyroModule[MLP](x_dim,[hidden_dim]*3 + [1], dropout=0.01)
    
    def forward(self, x):
        # print(f'FlowDistribution(x.shape={x.shape}, x.dim={x.dim()}')
        # if x.dim() == 1:
        #     x = x.unsqueeze(-1)
        x = x.reshape(-1,1)
        y_std = torch.exp(self.std_dist(x))[:,0]  # Ensure the standard deviation is positive
        return dist.Normal(0, y_std).to_event(1)

class InstrumentalModel(PyroModule):
    def __init__(self, z_dim, x_dim, hidden_dim):
        super().__init__()
        self.F_dist = FDistribution(z_dim, x_dim, hidden_dim)  # learnable
        self.g_fun = GFunction(x_dim, hidden_dim)  # learnable
        self.noise_distribution = NoiseDistribution(x_dim, hidden_dim)  # learnable

    def forward(self):
        z = pyro.sample('Z', dist.Normal(0, 1)).reshape(-1)
        d = self.F_dist(z)
        x = pyro.sample('X', d)
        # print(f'batch={d.batch_shape}, event={d.event_shape}, orig_x={x.shape}')
        x = x.squeeze(-1)
        # if len(x.shape) == 2:
        #     x = x[:,0]
        gx = self.g_fun(x)
        Gx = pyro.deterministic("G(X)", gx, event_dim=1)
        # Gx = pyro.sample('G(X)', dist.Delta(gx, event_dim=0), obs=gx, infer={"_deterministic": True})
        h = pyro.sample('h', dist.Normal(0, 1))
        e = pyro.sample('e', self.noise_distribution(z).to_event(-1))
        yval = Gx + e + h
        y = pyro.deterministic("Y", yval, event_dim=1)
        # y =  pyro.sample('Y', dist.Delta(yval,event_dim=1), obs=yval, infer={"_deterministic": True})
        return x, Gx,y, z

model = InstrumentalModel(1,1,10)
print(f'No plate: {[arg.shape for arg in model()]}')
with pyro.plate('data', 10, dim=-1):
    print(f'With plate: {[arg.shape for arg in model()]}')
# Out:
# No plate: [torch.Size([1]), torch.Size([1]), torch.Size([1]), torch.Size([1])]
# With plate: [torch.Size([10]), torch.Size([10]), torch.Size([10]), torch.Size([10])]

# %%
pyro.render_model(InstrumentalModel(1,1,10))

# %%
class ObservedInstrumentalModel(PyroModule):
    def __init__(self, instrumental_model, n):
        super().__init__()
        self.n = n
        self.instrumental_model = instrumental_model

    def forward(self, x_obs=None, y_obs=None, z_obs=None, batch_idx=None):
        with condition(data={'X': x_obs, 'Y': y_obs, 'Z': z_obs}):
            with pyro.plate('data', size=self.n, subsample=batch_idx):
                return self.instrumental_model()
        
x, y_mean,y, z=ObservedInstrumentalModel(InstrumentalModel(1,1,10),10)(x_obs=torch.rand(5),y_obs=torch.rand(5),z_obs=torch.rand(5), batch_idx= torch.randperm(10)[:5])
print(x.shape,y.shape,y_mean.shape,z.shape)

pyro.render_model(lambda : ObservedInstrumentalModel(InstrumentalModel(1,1,10),10)(x_obs=torch.rand(5),y_obs=torch.rand(5),z_obs=torch.rand(5), batch_idx= torch.randperm(10)[:5]))
# Out:
# torch.Size([5]) torch.Size([5]) torch.Size([5]) torch.Size([5])

# %%
import pytorch_lightning as pl

class LightningSVI(pl.LightningModule):
    def __init__(self, elbo: pyro.infer.elbo.ELBOModule, **optim_params):
        super().__init__()
        self.optim_params = dict(optim_params)
        self.elbo = elbo

    def configure_optimizers(self):
        return torch.optim.Adam(self.elbo.parameters(), **self.optim_params)

    def training_step(self, batch, batch_idx):
        x,y,z,idxs=batch
        # print(idxs)
        loss = self.elbo(x,y,z, batch_idx=idxs)
        self.log('train_loss', loss)
        return loss

# %%
x_obs[:3].float().to(device),y_obs[:3].float().to(device),z_obs[:3].float().to(device)
# Out:
# (tensor([-2.7872, -4.7357,  2.4892], device='mps:0'),
#  tensor([ 15.6365,  16.3537, -14.7430], device='mps:0'),
#  tensor([ 0.2765,  0.0192, -0.0592], device='mps:0'))

# %%
torch.set_default_dtype(torch.float32)
torch.set_default_device(('cuda' if torch.cuda.is_available() else ('mps' if torch.backends.mps.is_available() else 'cpu')))

device = torch.device(('cuda' if torch.cuda.is_available() else ('mps' if torch.backends.mps.is_available() else 'cpu')))
# device = torch.device('cpu')
accelerator = "mps"
devices = [0]

# Define dimensions
z_dim = 1
x_dim = 1
hidden_dim = 10
n = len(x_obs)
indices = torch.arange(0,n,device=device)
pyro.clear_param_store()

# Instantiate the model
instrumental_model = InstrumentalModel(z_dim, x_dim, hidden_dim)
observed_instrumental_model = ObservedInstrumentalModel(instrumental_model, n)

def create_plates(x_obs=None, y_obs=None, z_obs=None, batch_idx=None):
    return pyro.plate('data', size=n, subsample=batch_idx)

guide = pyro.infer.autoguide.AutoNormal(observed_instrumental_model, create_plates=create_plates)
elbo = Trace_ELBO()(observed_instrumental_model,guide).to(device)

# initialize parameters
# elbo(x_obs[:batch_size].float().to(device),y_obs[:batch_size].float().to(device),z_obs[:batch_size].float().to(device),batch_idx=torch.randperm(len(x_obs))[:batch_size]).to(device)
elbo(x_obs[:3].float().to(device),y_obs[:3].float().to(device),z_obs[:3].float().to(device), batch_idx=torch.randperm(n)[:3]).to(device)
# Out:
# tensor(1772448.8750, device='mps:0', grad_fn=<AddBackward0>)

# %%
[p for p in elbo.named_parameters()]
# Out:
# [('model.instrumental_model.F_dist.mean_dist.0.weight',
#   Parameter containing:
#   tensor([[-0.6651],
#           [ 0.8335],
#           [ 0.8625],
#           [ 0.0457],
#           [ 0.5710],
#           [-0.5422],
#           [-0.6218],
#           [ 0.8247],
#           [ 0.4872],
#           [-0.8506]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.0.bias',
#   Parameter containing:
#   tensor([-0.0381, -0.7191,  0.3927, -0.9822,  0.0789,  0.7464,  0.2099,  0.9594,
#            0.8486, -0.0866], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.3.weight',
#   Parameter containing:
#   tensor([[ 0.0580,  0.0338, -0.0248, -0.0084,  0.0780,  0.2894, -0.2684,  0.0538,
#            -0.2211, -0.0003],
#           [-0.1720,  0.0287,  0.1107, -0.0518, -0.1734, -0.0860,  0.1398,  0.1988,
#             0.0265,  0.2738],
#           [ 0.1273, -0.0803,  0.1238,  0.0833,  0.2500, -0.2177,  0.0814, -0.3039,
#             0.0194,  0.2457],
#           [ 0.1853,  0.1224, -0.0779, -0.0620,  0.0880,  0.2289, -0.0496, -0.2506,
#            -0.1661, -0.0802],
#           [-0.1625,  0.1742, -0.0850,  0.2200,  0.2467,  0.0062, -0.2314,  0.1286,
#             0.1089, -0.3014],
#           [-0.1625, -0.1145,  0.0530, -0.1617,  0.0810, -0.0906, -0.2314,  0.0511,
#             0.2854, -0.2278],
#           [-0.1832, -0.0383, -0.1198,  0.0159,  0.1416,  0.1900,  0.2849, -0.1315,
#             0.0106,  0.0033],
#           [-0.1996, -0.1375,  0.0393,  0.2721, -0.1173,  0.1163, -0.0390,  0.0793,
#             0.2919,  0.3040],
#           [ 0.1871,  0.0656, -0.0965, -0.2557,  0.2512,  0.0644, -0.0964, -0.0919,
#            -0.0803,  0.2194],
#           [-0.0287,  0.1281,  0.2989, -0.0023,  0.1488, -0.0850, -0.0122, -0.0689,
#             0.0150,  0.2329]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.3.bias',
#   Parameter containing:
#   tensor([-0.1591, -0.0207,  0.1057, -0.2420, -0.1386, -0.3085,  0.1095, -0.1872,
#            0.2802,  0.1013], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.6.weight',
#   Parameter containing:
#   tensor([[ 0.1689,  0.1907,  0.2438, -0.2775,  0.0762,  0.2096, -0.3073,  0.1222,
#             0.0416, -0.2906],
#           [ 0.2030,  0.0428, -0.0891,  0.0338, -0.2160, -0.2792,  0.1601,  0.0408,
#            -0.2550, -0.1162],
#           [ 0.3059, -0.1051, -0.0466, -0.2714,  0.1762,  0.1452, -0.2551,  0.2812,
#             0.1862,  0.2480],
#           [-0.1546, -0.2001,  0.1149, -0.1153,  0.0680,  0.2957,  0.1345,  0.0092,
#            -0.2299,  0.2862],
#           [-0.2087,  0.0697, -0.3128, -0.2849,  0.2864,  0.2671, -0.1130, -0.2721,
#            -0.1535, -0.2489],
#           [-0.0711,  0.1717, -0.1027,  0.1132, -0.1874,  0.0317,  0.1669, -0.0781,
#             0.0498, -0.0455],
#           [ 0.0413, -0.2672, -0.0113,  0.2022,  0.0681, -0.1798, -0.0243,  0.1839,
#            -0.1531,  0.1196],
#           [ 0.1385,  0.3104,  0.2325,  0.2204, -0.1252,  0.2432,  0.0467,  0.1062,
#             0.0026,  0.2076],
#           [-0.2827,  0.0766, -0.2600,  0.1255, -0.1362,  0.0808, -0.1923, -0.2544,
#            -0.0168,  0.3065],
#           [ 0.0124,  0.0420, -0.0948, -0.2655,  0.1951, -0.2136, -0.3077,  0.2164,
#            -0.1353, -0.2614]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.6.bias',
#   Parameter containing:
#   tensor([ 0.0332, -0.0334, -0.0213,  0.1540,  0.2760,  0.1945,  0.0726,  0.2404,
#            0.2939, -0.1878], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.9.weight',
#   Parameter containing:
#   tensor([[-0.2488,  0.0241,  0.2964,  0.1460,  0.0553, -0.1532,  0.2050, -0.0632,
#            -0.2355,  0.1262]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.mean_dist.9.bias',
#   Parameter containing:
#   tensor([-0.0821], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.0.weight',
#   Parameter containing:
#   tensor([[ 0.4419],
#           [ 0.3832],
#           [-0.8776],
#           [ 0.6241],
#           [ 0.0578],
#           [-0.1734],
#           [-0.8827],
#           [ 0.3448],
#           [ 0.6447],
#           [-0.0640]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.0.bias',
#   Parameter containing:
#   tensor([ 0.9599,  0.6607, -0.2998, -0.7455, -0.7640, -0.9722,  0.9829,  0.9767,
#           -0.4809,  0.4519], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.3.weight',
#   Parameter containing:
#   tensor([[ 0.0298, -0.0018,  0.1137,  0.1916,  0.2288, -0.0027, -0.2140,  0.1616,
#             0.1420,  0.1113],
#           [-0.1414, -0.1140, -0.0120,  0.2157, -0.2214,  0.0061,  0.2140, -0.0030,
#            -0.0730, -0.0882],
#           [ 0.1492, -0.1119, -0.3149, -0.2157, -0.2340,  0.1389, -0.0855,  0.0783,
#            -0.2680, -0.1884],
#           [-0.1435, -0.1342, -0.2913,  0.2624,  0.2620,  0.2063,  0.2337,  0.0608,
#            -0.0618, -0.2975],
#           [-0.1521, -0.2605,  0.1259, -0.2029, -0.2170,  0.1242, -0.1913,  0.0613,
#            -0.0060,  0.1150],
#           [ 0.2491, -0.0300,  0.0074,  0.0539, -0.2309, -0.2054,  0.1297, -0.0561,
#            -0.2753, -0.2030],
#           [ 0.1784, -0.0720,  0.2608, -0.1513,  0.2600, -0.1672, -0.2590,  0.1043,
#             0.0418,  0.0702],
#           [ 0.2365, -0.1387, -0.2076,  0.1622,  0.2751, -0.2071, -0.0863, -0.1831,
#             0.2895,  0.1404],
#           [ 0.2826,  0.0280, -0.0336,  0.2150,  0.2793,  0.2449,  0.0990,  0.1361,
#             0.2974,  0.2269],
#           [ 0.1489, -0.1395, -0.1407, -0.1011, -0.2435,  0.0019, -0.1706, -0.0032,
#             0.0960,  0.0385]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.3.bias',
#   Parameter containing:
#   tensor([-0.1880,  0.1430, -0.2835,  0.0789, -0.2632, -0.1085, -0.1963, -0.2656,
#           -0.2237, -0.2220], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.6.weight',
#   Parameter containing:
#   tensor([[-0.0656,  0.1266,  0.1559,  0.1089, -0.0363,  0.0714, -0.1086, -0.1957,
#            -0.1659, -0.1410],
#           [ 0.0123,  0.1876, -0.1307, -0.0983,  0.1182,  0.1422,  0.3135, -0.2788,
#             0.0102,  0.1942],
#           [ 0.3009,  0.1921, -0.2313,  0.2539, -0.1588, -0.0612,  0.0483, -0.2839,
#            -0.2932,  0.1461],
#           [ 0.0443, -0.1082, -0.0507, -0.0095, -0.1237, -0.2649, -0.1416, -0.0595,
#            -0.2369,  0.0375],
#           [ 0.1333, -0.0566, -0.0391, -0.2372,  0.2447, -0.0244,  0.2526,  0.1425,
#            -0.1864, -0.0690],
#           [-0.2341, -0.0918,  0.2260, -0.1029,  0.0475, -0.1226,  0.2815, -0.2749,
#            -0.1085,  0.1084],
#           [ 0.0523,  0.2419, -0.0563, -0.3155,  0.2266, -0.1128, -0.0681, -0.1264,
#            -0.2032,  0.0550],
#           [ 0.0201,  0.0536, -0.0562,  0.0239, -0.0154,  0.2126,  0.0287, -0.1912,
#            -0.2369,  0.0498],
#           [ 0.1508,  0.1071, -0.2564, -0.0687,  0.0819,  0.1870, -0.2420,  0.1262,
#             0.0133, -0.0735],
#           [ 0.1384,  0.1935,  0.2077,  0.2604, -0.0898,  0.2496,  0.2061, -0.0619,
#             0.1621,  0.2290]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.6.bias',
#   Parameter containing:
#   tensor([-0.1530,  0.0661, -0.0901, -0.2689,  0.0242,  0.2698,  0.1774, -0.0716,
#            0.0168,  0.2996], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.9.weight',
#   Parameter containing:
#   tensor([[-0.0798,  0.1294,  0.0279, -0.1712,  0.1236, -0.1300,  0.1710, -0.0029,
#            -0.0992,  0.1908]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.F_dist.var_dist.9.bias',
#   Parameter containing:
#   tensor([0.2679], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.0.weight',
#   Parameter containing:
#   tensor([[-0.8726],
#           [ 0.3466],
#           [ 0.5404],
#           [-0.5305],
#           [ 0.2932],
#           [ 0.5683],
#           [ 0.0651],
#           [ 0.8772],
#           [-0.3889],
#           [ 0.0833]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.0.bias',
#   Parameter containing:
#   tensor([-0.2096,  0.3703,  0.7335, -0.6036,  0.1590,  0.7436, -0.6805, -0.8437,
#           -0.5068,  0.6476], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.3.weight',
#   Parameter containing:
#   tensor([[-0.0699,  0.0919,  0.2569, -0.1500, -0.2409, -0.3067, -0.2115, -0.2229,
#            -0.1950, -0.1997],
#           [ 0.2991, -0.2476, -0.1574, -0.0182, -0.2636,  0.1706,  0.1347, -0.1271,
#             0.2878,  0.0920],
#           [ 0.0341,  0.0915,  0.2417, -0.2433, -0.2437,  0.1469,  0.0470,  0.2296,
#            -0.2834,  0.2855],
#           [-0.2682, -0.0947,  0.0684,  0.2614, -0.2057, -0.1025,  0.0501,  0.0731,
#             0.2941,  0.1042],
#           [ 0.0909, -0.2007,  0.1689, -0.2273, -0.1027,  0.1364,  0.0495, -0.1658,
#             0.0766,  0.2782],
#           [ 0.0577,  0.0200,  0.1561, -0.1874,  0.1644, -0.3140,  0.0952,  0.2878,
#             0.1088,  0.0581],
#           [ 0.1846,  0.1036,  0.0032, -0.0801, -0.1962,  0.1723, -0.2321, -0.2594,
#             0.0612,  0.1276],
#           [ 0.3043, -0.0883,  0.2211, -0.0549, -0.3153, -0.1874,  0.0021, -0.0122,
#            -0.1174, -0.1586],
#           [ 0.2990,  0.0984, -0.3087,  0.1382,  0.0665, -0.2861,  0.0349,  0.0359,
#            -0.0319,  0.0677],
#           [-0.2455, -0.0868,  0.1602,  0.1603,  0.0216,  0.2652,  0.2892, -0.0836,
#             0.3016,  0.0779]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.3.bias',
#   Parameter containing:
#   tensor([-0.0295,  0.3098, -0.1034,  0.2071, -0.1943,  0.2590,  0.2416, -0.0806,
#           -0.0072, -0.1577], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.6.weight',
#   Parameter containing:
#   tensor([[-0.2806,  0.1432,  0.2031,  0.1702,  0.2647, -0.0364,  0.1332,  0.3080,
#            -0.0457, -0.1890],
#           [ 0.2807,  0.0368,  0.1396, -0.0659, -0.0565, -0.1894,  0.3006, -0.2883,
#             0.2666, -0.0296],
#           [-0.0244, -0.2935, -0.2788,  0.0298,  0.0635,  0.3148, -0.3043, -0.2810,
#             0.2773,  0.1433],
#           [ 0.0438, -0.1733,  0.0793,  0.1451,  0.0758,  0.0014,  0.3114, -0.2074,
#             0.0226, -0.1349],
#           [-0.2348, -0.0958, -0.1846,  0.0440, -0.2698, -0.0873, -0.0024,  0.1932,
#             0.2316, -0.1076],
#           [-0.0478, -0.3015,  0.0816, -0.0336, -0.2898,  0.2284,  0.0757,  0.1284,
#            -0.2773, -0.0563],
#           [ 0.0422,  0.1345, -0.0496, -0.0584, -0.0952,  0.1464, -0.0836, -0.0197,
#            -0.0289, -0.0267],
#           [-0.0839,  0.0750, -0.2599, -0.2370,  0.3081,  0.0823,  0.2003, -0.0889,
#             0.2712,  0.3114],
#           [ 0.0526,  0.2425,  0.3018, -0.1147, -0.1509,  0.1809,  0.1521,  0.1932,
#             0.2886, -0.1371],
#           [-0.0421, -0.1929, -0.2614, -0.2429, -0.0022,  0.1482, -0.2896,  0.1127,
#             0.1504, -0.0225]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.6.bias',
#   Parameter containing:
#   tensor([ 0.1332, -0.2414, -0.2477,  0.0338, -0.2202, -0.1242,  0.1220, -0.0141,
#           -0.2899, -0.2293], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.9.weight',
#   Parameter containing:
#   tensor([[-0.1103,  0.2947,  0.0252, -0.2185, -0.2588,  0.1394, -0.0651,  0.1756,
#             0.3008,  0.1012]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.g_fun.mlp.9.bias',
#   Parameter containing:
#   tensor([0.0117], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.0.weight',
#   Parameter containing:
#   tensor([[ 0.3486],
#           [-0.0872],
#           [ 0.9374],
#           [-0.0575],
#           [-0.3256],
#           [-0.8576],
#           [-0.9177],
#           [-0.5022],
#           [-0.0587],
#           [-0.6032]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.0.bias',
#   Parameter containing:
#   tensor([-0.8637, -0.0501,  0.2381, -0.3141, -0.8016, -0.6473, -0.4757,  0.9837,
#            0.9217, -0.1590], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.3.weight',
#   Parameter containing:
#   tensor([[ 0.0818, -0.2152,  0.0349, -0.2471,  0.1931,  0.1900,  0.1983, -0.2130,
#            -0.1657,  0.3037],
#           [ 0.2266,  0.2706,  0.1303,  0.0642, -0.2547,  0.1108,  0.0880,  0.1891,
#            -0.0134, -0.0634],
#           [-0.3047, -0.0821,  0.1100, -0.1989,  0.1355,  0.1404,  0.2102,  0.1190,
#             0.2931,  0.0236],
#           [ 0.0213, -0.0784,  0.1606,  0.2433,  0.0865,  0.0861,  0.2755,  0.0922,
#             0.2890, -0.2027],
#           [ 0.2773,  0.1148, -0.1804,  0.0358, -0.2892, -0.0340, -0.0669,  0.1766,
#            -0.3039,  0.1937],
#           [-0.2936, -0.2252,  0.0046, -0.2669,  0.2885, -0.2366, -0.2929,  0.0996,
#             0.0276,  0.2074],
#           [ 0.1383, -0.0074, -0.1544, -0.1397,  0.2546, -0.1618, -0.1655, -0.2776,
#             0.1655,  0.1121],
#           [ 0.1659,  0.1951,  0.1615, -0.1440, -0.1785, -0.1677,  0.3095, -0.0560,
#            -0.1848,  0.0480],
#           [ 0.1277,  0.0201,  0.2030, -0.1175,  0.2409,  0.2024, -0.1970,  0.0020,
#             0.0052, -0.1178],
#           [-0.1040,  0.1324,  0.0417,  0.0094, -0.1687, -0.1997, -0.3078,  0.1582,
#            -0.2709,  0.0303]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.3.bias',
#   Parameter containing:
#   tensor([-0.1285,  0.0813,  0.0542,  0.2091, -0.0716,  0.0742,  0.2062, -0.2396,
#           -0.1949, -0.0558], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.6.weight',
#   Parameter containing:
#   tensor([[-0.2448,  0.1792,  0.1589, -0.1700, -0.1501,  0.1500, -0.0603,  0.0909,
#             0.2512, -0.0138],
#           [-0.3135,  0.2886, -0.3007,  0.0473, -0.2799,  0.0978, -0.2850,  0.2727,
#             0.2034, -0.0775],
#           [-0.1248,  0.2492,  0.1046,  0.0421, -0.2902,  0.2155,  0.0883, -0.2174,
#             0.1084, -0.1315],
#           [ 0.2076, -0.2161, -0.2588, -0.2075, -0.0656, -0.1811, -0.2675,  0.2275,
#            -0.2599,  0.3084],
#           [ 0.1484,  0.1698,  0.1878,  0.2117, -0.1014,  0.1483, -0.3087,  0.1088,
#             0.0776,  0.2537],
#           [ 0.0248, -0.0031, -0.1167, -0.1082,  0.2762,  0.0861, -0.1430,  0.0254,
#             0.1490, -0.0111],
#           [ 0.2808,  0.0583,  0.3024,  0.1385,  0.2701, -0.0025, -0.0082, -0.2972,
#             0.1036,  0.1655],
#           [ 0.1286,  0.0035,  0.3031, -0.2971,  0.2776,  0.1329, -0.0959, -0.2845,
#            -0.1279,  0.1203],
#           [-0.2190,  0.2995, -0.2261, -0.1365, -0.2631,  0.1075,  0.0736, -0.1463,
#             0.0762,  0.1617],
#           [ 0.0890,  0.2973,  0.2288,  0.1706,  0.2723, -0.2014, -0.2626,  0.0762,
#             0.1522,  0.3056]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.6.bias',
#   Parameter containing:
#   tensor([-0.1836, -0.2608,  0.2387,  0.0773, -0.1310, -0.1402,  0.0046,  0.2332,
#           -0.0812, -0.1685], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.9.weight',
#   Parameter containing:
#   tensor([[ 0.0126, -0.0354,  0.0416,  0.1719, -0.2787,  0.2574,  0.0135, -0.0461,
#             0.0021, -0.1435]], device='mps:0', requires_grad=True)),
#  ('model.instrumental_model.noise_distribution.std_dist.9.bias',
#   Parameter containing:
#   tensor([0.0110], device='mps:0', requires_grad=True)),
#  ('guide.locs.h_unconstrained',
#   Parameter containing:
#   tensor([0., 0., 0.,  ..., 0., 0., 0.], device='mps:0', requires_grad=True)),
#  ('guide.locs.e_unconstrained',
#   Parameter containing:
#   tensor([0., 0., 0.,  ..., 0., 0., 0.], device='mps:0', requires_grad=True)),
#  ('guide.scales.h_unconstrained',
#   Parameter containing:
#   tensor([-2.2522, -2.2522, -2.2522,  ..., -2.2522, -2.2522, -2.2522],
#          device='mps:0', requires_grad=True)),
#  ('guide.scales.e_unconstrained',
#   Parameter containing:
#   tensor([-2.2522, -2.2522, -2.2522,  ..., -2.2522, -2.2522, -2.2522],
#          device='mps:0', requires_grad=True))]

# %%
# fit parameters
from torch.utils.data import TensorDataset, DataLoader
from pytorch_lightning.loggers import TensorBoardLogger

batch_size= 2048
max_epochs = 10

dataset = TensorDataset(x_obs.float().to(device),y_obs.float().to(device),z_obs.float().to(device),indices)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False) # bug on MacOS if shuffle=True

svi = LightningSVI(elbo, lr=0.001)
trainer = pl.Trainer(max_epochs=max_epochs, log_every_n_steps=1, accelerator=accelerator, devices=devices,
                     logger=TensorBoardLogger("lightning_logs", name="instrumental_model")
)


trainer.fit(svi, train_dataloaders=dataloader)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name | Type       | Params | Mode
# --------------------------------------------
# 0 | elbo | ELBOModule | 401 K  | train
# --------------------------------------------
# 401 K     Trainable params
# 0         Non-trainable params
# 401 K     Total params
# 1.604     Total estimated model params size (MB)
# /Users/dima/git/chirho/.conda/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.

# %%
num_mc_samples = 500

with MultiWorldCounterfactual(),do(actions=dict(X=(torch.tensor(0.),torch.tensor(1.)))):
    samples = Predictive(instrumental_model.to(device), num_samples=num_mc_samples).get_samples()

display([(k,v.shape) for k,v in samples.items()])

plt.figure(figsize=(10,3))
plt.subplot(121)
plt.plot(samples['G(X)'].cpu().numpy())
plt.legend(['Xorig','X=0','X=1'])
plt.title('G(x)')
plt.subplot(122)
plt.plot(samples['Y'].cpu().numpy())
plt.legend(['Xorig','X=0','X=1'])
plt.title('Y')
plt.subplots_adjust(wspace=0.2)
plt.show()
# Out:
# [('Z', torch.Size([500])),
#  ('X', torch.Size([500, 3, 1, 1, 1, 1, 1])),
#  ('h', torch.Size([500])),
#  ('e', torch.Size([500, 1])),
#  ('G(X)', torch.Size([500, 3])),
#  ('Y', torch.Size([500, 3]))]

# %%
num_mc_samples = 500

with MultiWorldCounterfactual(),do(actions=dict(Z=(torch.tensor(0.),torch.tensor(1.)))):
    samples = Predictive(instrumental_model.to(device), num_samples=num_mc_samples).get_samples()

display([(k,v.shape) for k,v in samples.items()])

plt.figure(figsize=(10,3))
plt.subplot(121)
plt.plot(samples['X'].squeeze().cpu().numpy())
plt.legend(['Zorig','Z=0','Z=1'])
plt.title('X')
plt.subplot(122)
plt.plot(samples['Y'].cpu().numpy())
plt.legend(['Zorig','Z=0','Z=1'])
plt.title('Y')
plt.subplots_adjust(wspace=0.2)
plt.show()
# Out:
# [('Z', torch.Size([500, 3, 1, 1, 1, 1])),
#  ('X', torch.Size([500, 3, 1])),
#  ('h', torch.Size([500])),
#  ('e', torch.Size([500, 3])),
#  ('G(X)', torch.Size([500, 3])),
#  ('Y', torch.Size([500, 3]))]

# %%
num_mc_samples = 500

with MultiWorldCounterfactual(),do(actions=dict(X=(torch.tensor(0.),torch.tensor(1.)))):
    samples = Predictive(instrumental_model, num_samples=num_mc_samples).get_samples()
    y_all, gx_all = samples['Y'],samples['G(X)']
    y_cf_1 = y_all[:,2]
    y_cf_0 = y_all[:,1]
    ate = (y_cf_1 - y_cf_0).mean()
    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}')
    print(f'ate_direct={ate}')

    gx_cf_1 = gx_all[:,2]
    gx_cf_0 = gx_all[:,1]
    gxz = (gx_cf_1 - gx_cf_0).mean()
    print(f'Shapes G(X): {gx_cf_1.shape}, {gx_cf_0.shape}')
    print(f'gxz={gxz}')
        

# now the two-stage approach
with MultiWorldCounterfactual(), do(actions=dict(Z=(torch.tensor(0.),torch.tensor(1.)))):
    samples = Predictive(instrumental_model, num_samples=num_mc_samples).get_samples()
    x_all,y_all = samples['X'],samples['Y']

    y_cf_1 = y_all[:,2]
    y_cf_0 = y_all[:,1]

    x_cf_1 = x_all[:,2]
    x_cf_0 = x_all[:,1]

    xz = (x_cf_1 - x_cf_0).mean()
    yz = (y_cf_1 - y_cf_0).mean()

    print(f'Shapes Y: {y_cf_1.shape}, {y_cf_0.shape}, X: {x_cf_1.shape}, {x_cf_0.shape}')

    ate = yz / xz
    print(f'xz = {xz}, yz = {yz}, ate_2sls = {ate}')

# plot the distributions
# sns.histplot((y_cf_1-y_cf_0).mean(dim=-1).squeeze().detach().cpu().numpy(), bins=20, kde=True, color='blue', label='Y-Z')
# sns.histplot((x_cf_1-x_cf_0).mean(dim=-1).squeeze().detach().cpu().numpy(), bins=20, kde=True, color='red', label='X-Z')
# sns.histplot(((y_cf_1-y_cf_0).mean(dim=-1)/(x_cf_1-x_cf_0).mean(dim=-1)).squeeze().detach().cpu().numpy(), bins=20, kde=True, color='green', label='ATE')
# plt.xlabel('ATE')
# plt.ylabel('Density')
# plt.title(f'ATE posterior distribution:\nTrue XY={true_alpha}, XZ={true_beta}, YZ={true_alpha*true_beta}')
# plt.legend()
# plt.show()
# Out:
# Shapes Y: torch.Size([500]), torch.Size([500])
# ate_direct=-0.03210803493857384
# Shapes G(X): torch.Size([500]), torch.Size([500])
# gxz=-0.03210803493857384
# Shapes Y: torch.Size([500]), torch.Size([500]), X: torch.Size([500, 1]), torch.Size([500, 1])
# xz = -0.21822784841060638, yz = 0.0055190823040902615, ate_2sls = -0.025290457531809807

# %%
# What about the untrained model?
x_test = torch.linspace(-2,2,150).float().to(device)
with pyro.condition(data={'X': x_test}):
    x_test_p,Gx_test,y_test,z_test = instrumental_model()

plt.scatter(x_test.cpu().detach().numpy(),y_test.cpu().detach().numpy(), label='Y')
plt.scatter(x_test.cpu().detach().numpy(),Gx_test.cpu().detach().numpy(), label='G(x)')
plt.xlabel('X')
plt.legend()
plt.show()

# %%
# What about the untrained model?
x_test = torch.linspace(-2,2,150).float().to(device)
untrained_model = InstrumentalModel(1, 1, 50).to(device)
with pyro.condition(data={'X': x_test}):
    x_test_p,Gx_test,y_test,z_test = untrained_model()

plt.scatter(x_test.cpu().detach().numpy(),y_test.cpu().detach().numpy(), label='Y')
plt.scatter(x_test.cpu().detach().numpy(),Gx_test.cpu().detach().numpy(), label='G(x)')
plt.xlabel('X')
plt.legend()
plt.show()
